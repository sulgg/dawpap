# %%
import os
import numpy as np
import pandas as pd
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.utils import AnalysisException

# %%
spark = (SparkSession
         .builder
         .getOrCreate())

# %%
DIRECTORY = "../../data/broadcast_logs"
# FILE = "BroadcastLogs_2018_Q3_M8.CSV"
FILE = "BroadcastLogs_2018_Q3_M8_sample.CSV"

# %%
logs = spark.read.csv(
    path=os.path.join(DIRECTORY, FILE),
    sep="|",
    header=True,
    inferSchema=True,
    timestampFormat="yyyy-MM-dd",
    )

# %%
def split_table(df, sections, records):
    col_split = np.array_split(np.array(logs.columns), sections)
    for x in col_split:
        df.select(*x).show(records, False)

# %%
split_table(logs, 3, 3)
# Out:
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+
# |BroadcastLogID|LogServiceID|LogDate   |SequenceNO|AudienceTargetAgeID|AudienceTargetEthnicID|CategoryID|ClosedCaptionID|CountryOfOriginID|DubDramaCreditID|
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+
# |1196192316    |3157        |2018-08-01|1         |4                  |NULL                  |13        |3              |3                |NULL            |
# |1196192317    |3157        |2018-08-01|2         |NULL               |NULL                  |NULL      |1              |NULL             |NULL            |
# |1196192318    |3157        |2018-08-01|3         |NULL               |NULL                  |NULL      |1              |NULL             |NULL            |
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+
# only showing top 3 rows
#
# +---------------+------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+
# |EthnicProgramID|ProductionSourceID|ProgramClassID|FilmClassificationID|ExhibitionID|Duration        |EndTime         |LogEntryDate|ProductionNO|ProgramTitle                              |
# +---------------+------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+
# |NULL           |10                |19            |NULL                |2           |02:00:00.0000000|08:00:00.0000000|2018-08-01  |A39082      |Newlywed and Dead                         |
# |NULL           |NULL              |20            |NULL                |NULL        |00:00:30.0000000|06:13:45.0000000|2018-08-01  |NULL        |15-SPECIALTY CHANNELS-Canadian Generic    |
# |NULL           |NULL              |3             |NULL                |NULL        |00:00:15.0000000|06:14:00.0000000|2018-08-01  |NULL        |3-PROCTER & GAMBLE INC-Anti-Perspirant 3rd|
# +---------------+------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+
# only showing top 3 rows
#
# +----------------+--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+
# |StartTime       |Subtitle|NetworkAffiliationID|SpecialAttentionID|BroadcastOriginPointID|CompositionID|Producer1|Producer2|Language1|Language2|
# +----------------+--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+
# |06:00:00.0000000|NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |94       |NULL     |
# |06:13:15.0000000|NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |NULL     |NULL     |
# |06:13:45.0000000|NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |NULL     |NULL     |
# +----------------+--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+
# only showing top 3 rows

# %%
logs.select(F.col("Duration")).dtypes
# Out:
# [('Duration', 'string')]

# %%
logs.select(
    F.col("Duration"),
    F.col("Duration").substr(1, 2).cast("int").alias("dur_hours"),
    F.col("Duration").substr(4, 2).cast("int").alias("dur_minutes"),
    F.col("Duration").substr(7, 2).cast("int").alias("dur_seconds"),
    ).show()
# Out:
# +----------------+---------+-----------+-----------+
# |        Duration|dur_hours|dur_minutes|dur_seconds|
# +----------------+---------+-----------+-----------+
# |02:00:00.0000000|        2|          0|          0|
# |00:00:30.0000000|        0|          0|         30|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:30.0000000|        0|          0|         30|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:30.0000000|        0|          0|         30|
# |00:00:30.0000000|        0|          0|         30|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:00:15.0000000|        0|          0|         15|
# |00:01:00.0000000|        0|          1|          0|
# |00:00:15.0000000|        0|          0|         15|
# +----------------+---------+-----------+-----------+
# only showing top 20 rows

# %% [markdown]
# El df sigue sin modificaciones:

# %%
split_table(logs, 3, 3)
# Out:
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+
# |BroadcastLogID|LogServiceID|LogDate   |SequenceNO|AudienceTargetAgeID|AudienceTargetEthnicID|CategoryID|ClosedCaptionID|CountryOfOriginID|DubDramaCreditID|
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+
# |1196192316    |3157        |2018-08-01|1         |4                  |NULL                  |13        |3              |3                |NULL            |
# |1196192317    |3157        |2018-08-01|2         |NULL               |NULL                  |NULL      |1              |NULL             |NULL            |
# |1196192318    |3157        |2018-08-01|3         |NULL               |NULL                  |NULL      |1              |NULL             |NULL            |
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+
# only showing top 3 rows
#
# +---------------+------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+
# |EthnicProgramID|ProductionSourceID|ProgramClassID|FilmClassificationID|ExhibitionID|Duration        |EndTime         |LogEntryDate|ProductionNO|ProgramTitle                              |
# +---------------+------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+
# |NULL           |10                |19            |NULL                |2           |02:00:00.0000000|08:00:00.0000000|2018-08-01  |A39082      |Newlywed and Dead                         |
# |NULL           |NULL              |20            |NULL                |NULL        |00:00:30.0000000|06:13:45.0000000|2018-08-01  |NULL        |15-SPECIALTY CHANNELS-Canadian Generic    |
# |NULL           |NULL              |3             |NULL                |NULL        |00:00:15.0000000|06:14:00.0000000|2018-08-01  |NULL        |3-PROCTER & GAMBLE INC-Anti-Perspirant 3rd|
# +---------------+------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+
# only showing top 3 rows
#
# +----------------+--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+
# |StartTime       |Subtitle|NetworkAffiliationID|SpecialAttentionID|BroadcastOriginPointID|CompositionID|Producer1|Producer2|Language1|Language2|
# +----------------+--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+
# |06:00:00.0000000|NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |94       |NULL     |
# |06:13:15.0000000|NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |NULL     |NULL     |
# |06:13:45.0000000|NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |NULL     |NULL     |
# +----------------+--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+
# only showing top 3 rows

# %% [markdown]
# `withColumn` agrega la(s) columna(s) a diferencia de `select` que solo crea un nuevo df con las nuevas columnas

# %%
logs = logs.withColumn(
    "Duration_seconds", (
        F.col("Duration").substr(1, 2).cast("int") * 3600
        + F.col("Duration").substr(4, 2).cast("int") * 60
        + F.col("Duration").substr(7, 2).cast("int")
        ),
        )

# %%
split_table(logs, 3, 3)
# Out:
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+---------------+
# |BroadcastLogID|LogServiceID|LogDate   |SequenceNO|AudienceTargetAgeID|AudienceTargetEthnicID|CategoryID|ClosedCaptionID|CountryOfOriginID|DubDramaCreditID|EthnicProgramID|
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+---------------+
# |1196192316    |3157        |2018-08-01|1         |4                  |NULL                  |13        |3              |3                |NULL            |NULL           |
# |1196192317    |3157        |2018-08-01|2         |NULL               |NULL                  |NULL      |1              |NULL             |NULL            |NULL           |
# |1196192318    |3157        |2018-08-01|3         |NULL               |NULL                  |NULL      |1              |NULL             |NULL            |NULL           |
# +--------------+------------+----------+----------+-------------------+----------------------+----------+---------------+-----------------+----------------+---------------+
# only showing top 3 rows
#
# +------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+----------------+
# |ProductionSourceID|ProgramClassID|FilmClassificationID|ExhibitionID|Duration        |EndTime         |LogEntryDate|ProductionNO|ProgramTitle                              |StartTime       |
# +------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+----------------+
# |10                |19            |NULL                |2           |02:00:00.0000000|08:00:00.0000000|2018-08-01  |A39082      |Newlywed and Dead                         |06:00:00.0000000|
# |NULL              |20            |NULL                |NULL        |00:00:30.0000000|06:13:45.0000000|2018-08-01  |NULL        |15-SPECIALTY CHANNELS-Canadian Generic    |06:13:15.0000000|
# |NULL              |3             |NULL                |NULL        |00:00:15.0000000|06:14:00.0000000|2018-08-01  |NULL        |3-PROCTER & GAMBLE INC-Anti-Perspirant 3rd|06:13:45.0000000|
# +------------------+--------------+--------------------+------------+----------------+----------------+------------+------------+------------------------------------------+----------------+
# only showing top 3 rows
#
# +--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+----------------+
# |Subtitle|NetworkAffiliationID|SpecialAttentionID|BroadcastOriginPointID|CompositionID|Producer1|Producer2|Language1|Language2|Duration_seconds|
# +--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+----------------+
# |NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |94       |NULL     |7200            |
# |NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |NULL     |NULL     |30              |
# |NULL    |NULL                |NULL              |NULL                  |NULL         |NULL     |NULL     |NULL     |NULL     |15              |
# +--------+--------------------+------------------+----------------------+-------------+---------+---------+---------+---------+----------------+
# only showing top 3 rows

# %% [markdown]
# Pasar todos los nombres de columna a minuscula

# %%
def to_snake_case(word):
    return (''
            .join(
                ['_'+ i.lower() if i.isupper() else i for i in word]
                )
            .replace("_i_d", "_id")
            .replace("_n_o", "_no")
            .lstrip('_'))

# %%
logs = logs.toDF(*[to_snake_case(x) for x in logs.columns])
logs = logs.select(sorted(logs.columns))

# %%
split_table(logs, 3, 3)
# Out:
# +----------------------+-------------------------+----------------+-------------------------+-----------+-----------------+--------------+--------------------+-------------------+----------------+----------------+
# |audience_target_age_id|audience_target_ethnic_id|broadcast_log_id|broadcast_origin_point_id|category_id|closed_caption_id|composition_id|country_of_origin_id|dub_drama_credit_id|duration        |duration_seconds|
# +----------------------+-------------------------+----------------+-------------------------+-----------+-----------------+--------------+--------------------+-------------------+----------------+----------------+
# |4                     |NULL                     |1196192316      |NULL                     |13         |3                |NULL          |3                   |NULL               |02:00:00.0000000|7200            |
# |NULL                  |NULL                     |1196192317      |NULL                     |NULL       |1                |NULL          |NULL                |NULL               |00:00:30.0000000|30              |
# |NULL                  |NULL                     |1196192318      |NULL                     |NULL       |1                |NULL          |NULL                |NULL               |00:00:15.0000000|15              |
# +----------------------+-------------------------+----------------+-------------------------+-----------+-----------------+--------------+--------------------+-------------------+----------------+----------------+
# only showing top 3 rows
#
# +----------------+-----------------+-------------+----------------------+---------+---------+----------+--------------+--------------+----------------------+
# |end_time        |ethnic_program_id|exhibition_id|film_classification_id|language1|language2|log_date  |log_entry_date|log_service_id|network_affiliation_id|
# +----------------+-----------------+-------------+----------------------+---------+---------+----------+--------------+--------------+----------------------+
# |08:00:00.0000000|NULL             |2            |NULL                  |94       |NULL     |2018-08-01|2018-08-01    |3157          |NULL                  |
# |06:13:45.0000000|NULL             |NULL         |NULL                  |NULL     |NULL     |2018-08-01|2018-08-01    |3157          |NULL                  |
# |06:14:00.0000000|NULL             |NULL         |NULL                  |NULL     |NULL     |2018-08-01|2018-08-01    |3157          |NULL                  |
# +----------------+-----------------+-------------+----------------------+---------+---------+----------+--------------+--------------+----------------------+
# only showing top 3 rows
#
# +---------+---------+-------------+--------------------+----------------+------------------------------------------+-----------+--------------------+----------------+--------+
# |producer1|producer2|production_no|production_source_id|program_class_id|program_title                             |sequence_no|special_attention_id|start_time      |subtitle|
# +---------+---------+-------------+--------------------+----------------+------------------------------------------+-----------+--------------------+----------------+--------+
# |NULL     |NULL     |A39082       |10                  |19              |Newlywed and Dead                         |1          |NULL                |06:00:00.0000000|NULL    |
# |NULL     |NULL     |NULL         |NULL                |20              |15-SPECIALTY CHANNELS-Canadian Generic    |2          |NULL                |06:13:15.0000000|NULL    |
# |NULL     |NULL     |NULL         |NULL                |3               |3-PROCTER & GAMBLE INC-Anti-Perspirant 3rd|3          |NULL                |06:13:45.0000000|NULL    |
# +---------+---------+-------------+--------------------+----------------+------------------------------------------+-----------+--------------------+----------------+--------+
# only showing top 3 rows

# %%
logs.describe().toPandas().set_index('summary').T
# Out:
# summary                     count                  mean                stddev  \
# audience_target_age_id      16112    3.4929245283018866    1.0415963394745122
# audience_target_ethnic_id    1710    120.56432748538012     71.98694059436134
# broadcast_log_id           238945  1.2168651122760174E9  1.4969134241431221E7
# broadcast_origin_point_id    9978    2.1390058127881337    0.9323192037553315
# category_id                 25506    18.485297577040697     9.655852252020837
# closed_caption_id          224117    1.0316174141185184   0.24947032900378902
# composition_id               9978    3.4141110442974543    0.9338603403654636
# country_of_origin_id        17822      4.06390977443609    2.6159675821007315
# dub_drama_credit_id           263    5.1254752851711025     3.451329711438564
# duration                   236724                  None                  None
# duration_seconds           236724    124.30587942076004     573.7742807594924
# end_time                   169979                  None                  None
# ethnic_program_id            1895     4.316622691292876    2.2966421456800283
# exhibition_id                9263      4.52067364784627    1.4418772626833447
# film_classification_id       1885     1.953315649867374    1.6420515263133844
# language1                   12586    101.75377403464167     45.68403685468214
# language2                    2629    175.49334347660707     86.03603792883949
# log_service_id             238945     3450.890284375065    199.50673962554782
# network_affiliation_id     108807     6.082200593711802    2.9908486752285337
# producer1                    2607                  None                  None
# producer2                      38                  None                  None
# production_no                3519     35710.61538461538    3749.1340008607654
# production_source_id        16223    11.193737286568453     6.079022239331339
# program_class_id           238945      8.49341061750612     7.902116846905779
# program_title              238703                1999.0                  None
# sequence_no                238945     466.3855824562138    311.51091048397865
# special_attention_id         2395     1.704384133611691    0.5394635034869694
# start_time                 238945                  None                  None
# subtitle                    15468     3463.573913043478    16251.272419144227
#
# summary                                 min  \
# audience_target_age_id                    1
# audience_target_ethnic_id                 4
# broadcast_log_id                 1195788151
# broadcast_origin_point_id                 1
# category_id                               1
# closed_caption_id                         1
# composition_id                            1
# country_of_origin_id                      2
# dub_drama_credit_id                       1
# duration                   00:00:01.0000000
# duration_seconds                          1
# end_time                   00:00:00.0000000
# ethnic_program_id                         1
# exhibition_id                             1
# film_classification_id                    1
# language1                                94
# language2                                 3
# log_service_id                         3157
# network_affiliation_id                    1
# producer1                               AMI
# producer2                             NEWSW
# production_no                        030641
# production_source_id                      1
# program_class_id                          3
# program_title              !NO 5PM A ID(:5)
# sequence_no                               1
# special_attention_id                      1
# start_time                 00:00:00.0000000
# subtitle                               #001
#
# summary                                                                  max
# audience_target_age_id                                                     4
# audience_target_ethnic_id                                                337
# broadcast_log_id                                                  1249431576
# broadcast_origin_point_id                                                  3
# category_id                                                               29
# closed_caption_id                                                          3
# composition_id                                                             4
# country_of_origin_id                                                      11
# dub_drama_credit_id                                                       10
# duration                                                    06:30:09.0000000
# duration_seconds                                                       23409
# end_time                                                    23:59:59.0000000
# ethnic_program_id                                                          6
# exhibition_id                                                              8
# film_classification_id                                                     8
# language1                                                                437
# language2                                                                438
# log_service_id                                                          3925
# network_affiliation_id                                                     9
# producer1                                                             VISION
# producer2                                                                 QC
# production_no                                                         c34183
# production_source_id                                                      19
# program_class_id                                                          30
# program_title                                             �t� avec Jo�l 2/Un
# sequence_no                                                             1463
# special_attention_id                                                       3
# start_time                                                  23:59:59.0000000
# subtitle                   �tre dans le trouble                    EP#048...
